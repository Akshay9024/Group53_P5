# %%
import os
import cv2
import torch
import csv
import torchvision.ops as ops
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
# ─── 0. Configuration ─────────────────────────────────────────────────────────
input_folder  = "./videos"
output_folder = "./output_videos"
os.makedirs(output_folder, exist_ok=True)

SKIP     = 1
IMG_SIZE = 512
device   = 0

# ─── 1. Prepare CSV log ───────────────────────────────────────────────────────
log_path = os.path.join(output_folder, "tracking_log.csv")
with open(log_path, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["video", "frame_id", "track_id", "x1", "y1", "x2", "y2"])

# ─── 2. Load models + tracker ─────────────────────────────────────────────────
head_model = YOLO("head_medium.pt")
body_model = YOLO("yolov8n.pt")
tracker    = DeepSort(max_age=30)

# ─── 3. Process videos 01.mp4 → 20.mp4 ────────────────────────────────────────
for i in range(1, 21):
    vid_name = f"{i:02}.mp4"
    in_path  = os.path.join(input_folder, vid_name)
    out_path = os.path.join(output_folder, f"tracked_{vid_name}")

    if not os.path.isfile(in_path):
        print(f"  Skipping missing {vid_name}")
        continue

    print(f"  Processing {vid_name}")
    cap = cv2.VideoCapture(in_path)
    fps    = cap.get(cv2.CAP_PROP_FPS) or 30
    w      = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h      = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out    = cv2.VideoWriter(out_path, fourcc, fps, (w, h))

    frame_id = 0
    tracks   = []  # to keep last tracks between skips

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # ─── A. Inference & tracking every SKIP frames ────────────────
        if frame_id % SKIP == 0:
            # Detect heads and bodies
            head_res = head_model(frame, conf=0.15, iou=0.5, imgsz=IMG_SIZE)[0]
            body_res = body_model(frame, conf=0.2,  iou=0.5, imgsz=IMG_SIZE)[0]

            # Collect detections: [x1,y1,x2,y2,conf,cls]
            dets = []
            for x1,y1,x2,y2,conf,cls in head_res.boxes.data.tolist():
                dets.append([x1,y1,x2,y2,conf,1])
            for x1,y1,x2,y2,conf,cls in body_res.boxes.data.tolist():
                if int(cls) == 0:
                    dets.append([x1,y1,x2,y2,conf,0])

            # NMS
            if dets:
                dt   = torch.tensor(dets)
                keep = ops.nms(dt[:,:4], dt[:,4], iou_threshold=0.5)
                final = dt[keep]
            else:
                final = torch.empty((0,6))

            # Prep for DeepSORT
            to_track = [
                ([x1, y1, x2-x1, y2-y1], float(conf), int(cls))
                for x1,y1,x2,y2,conf,cls in final.tolist()
            ]

            # Update tracker
            tracks = tracker.update_tracks(to_track, frame=frame)

        # ─── B. Draw & log every confirmed track ────────────────────────
        with open(log_path, "a", newline="") as csvfile:
            writer = csv.writer(csvfile)
            for tr in tracks:
                if not tr.is_confirmed():
                    continue
                x1, y1, x2, y2 = map(int, tr.to_ltrb())
                # draw box
                cls   = getattr(tr, "det_class", None)
                color = (255,0,0) if cls==0 else (0,255,0)
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                # log bbox coords
                writer.writerow([vid_name, frame_id, tr.track_id, x1, y1, x2, y2])

        # ─── C. Always write every frame ────────────────────────────────
        out.write(frame)
        frame_id += 1

    cap.release()
    out.release()
    print(f"  Saved {out_path}")

print(f"  Done! Log saved at {log_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 0: 288x512 1 head, 640.7ms
# Speed: 6.2ms preprocess, 640.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 92.3ms
# Speed: 6.0ms preprocess, 92.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 492.6ms
# Speed: 2.6ms preprocess, 492.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 89.3ms
# Speed: 2.7ms preprocess, 89.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 503.5ms
# Speed: 2.5ms preprocess, 503.5ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 84.9ms
# Speed: 2.9ms preprocess, 84.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 512.4ms
# Speed: 2.6ms preprocess, 512.4ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 87.9ms
# Speed: 2.9ms preprocess, 87.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 499.4ms
# Speed: 2.5ms preprocess, 499.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.1ms
# Speed: 2.6ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 493.3ms
# Speed: 2.6ms preprocess, 493.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.0ms
# Speed: 2.9ms preprocess, 88.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 505.6ms
# Speed: 2.6ms preprocess, 505.6ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.2ms
# Speed: 2.5ms preprocess, 88.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 498.5ms
# Speed: 2.6ms preprocess, 498.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 85.1ms
# Speed: 4.0ms preprocess, 85.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 487.1ms
# Speed: 2.8ms preprocess, 487.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.7ms
# Speed: 2.8ms preprocess, 88.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 496.5ms
# Speed: 2.6ms preprocess, 496.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 86.9ms
# Speed: 2.8ms preprocess, 86.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 497.6ms
# Speed: 2.5ms preprocess, 497.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 92.3ms
# Speed: 2.5ms preprocess, 92.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 501.5ms
# Speed: 4.4ms preprocess, 501.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 90.2ms
# Speed: 2.9ms preprocess, 90.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 486.8ms
# Speed: 2.6ms preprocess, 486.8ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 90.1ms
# Speed: 2.7ms preprocess, 90.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 653.3ms
# Speed: 4.3ms preprocess, 653.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 127.7ms
# Speed: 3.5ms preprocess, 127.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 762.7ms
# Speed: 2.9ms preprocess, 762.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 149.9ms
# Speed: 3.0ms preprocess, 149.9ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 694.4ms
# Speed: 2.7ms preprocess, 694.4ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 99.7ms
# Speed: 2.9ms preprocess, 99.7ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 512.2ms
# Speed: 2.5ms preprocess, 512.2ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 93.0ms
# Speed: 3.6ms preprocess, 93.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 495.2ms
# Speed: 4.5ms preprocess, 495.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 86.9ms
# Speed: 2.8ms preprocess, 86.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 510.0ms
# Speed: 2.7ms preprocess, 510.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.3ms
# Speed: 2.7ms preprocess, 88.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 503.5ms
# Speed: 3.0ms preprocess, 503.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 110.5ms
# Speed: 2.8ms preprocess, 110.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 491.0ms
# Speed: 2.6ms preprocess, 491.0ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 89.6ms
# Speed: 2.6ms preprocess, 89.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 487.4ms
# Speed: 3.6ms preprocess, 487.4ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 87.7ms
# Speed: 2.7ms preprocess, 87.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 521.4ms
# Speed: 2.7ms preprocess, 521.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 87.1ms
# Speed: 2.8ms preprocess, 87.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 527.8ms
# Speed: 5.7ms preprocess, 527.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 87.3ms
# Speed: 2.8ms preprocess, 87.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 527.6ms
# Speed: 3.1ms preprocess, 527.6ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 107.1ms
# Speed: 2.7ms preprocess, 107.1ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 heads, 511.2ms
# Speed: 3.0ms preprocess, 511.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 105.9ms
# Speed: 2.6ms preprocess, 105.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 514.5ms
# Speed: 7.2ms preprocess, 514.5ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 95.9ms
# Speed: 3.1ms preprocess, 95.9ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 614.3ms
# Speed: 2.7ms preprocess, 614.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 135.4ms
# Speed: 2.6ms preprocess, 135.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 766.8ms
# Speed: 2.8ms preprocess, 766.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 142.2ms
# Speed: 2.8ms preprocess, 142.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 707.8ms
# Speed: 6.4ms preprocess, 707.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 129.1ms
# Speed: 2.6ms preprocess, 129.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 517.7ms
# Speed: 2.7ms preprocess, 517.7ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 90.8ms
# Speed: 2.5ms preprocess, 90.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 511.5ms
# Speed: 3.0ms preprocess, 511.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 89.0ms
# Speed: 2.7ms preprocess, 89.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 519.0ms
# Speed: 3.3ms preprocess, 519.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 96.0ms
# Speed: 3.0ms preprocess, 96.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 531.0ms
# Speed: 3.0ms preprocess, 531.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 91.6ms
# Speed: 2.9ms preprocess, 91.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 533.0ms
# Speed: 5.7ms preprocess, 533.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 118.1ms
# Speed: 2.5ms preprocess, 118.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 532.0ms
# Speed: 5.8ms preprocess, 532.0ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 87.3ms
# Speed: 2.6ms preprocess, 87.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 heads, 514.0ms
# Speed: 3.2ms preprocess, 514.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 102.6ms
# Speed: 2.6ms preprocess, 102.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 heads, 512.6ms
# Speed: 2.7ms preprocess, 512.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 90.0ms
# Speed: 2.6ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 heads, 516.8ms
# Speed: 2.9ms preprocess, 516.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 85.9ms
# Speed: 2.9ms preprocess, 85.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 516.2ms
# Speed: 3.0ms preprocess, 516.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 116.6ms
# Speed: 2.9ms preprocess, 116.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 631.5ms
# Speed: 3.5ms preprocess, 631.5ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 135.9ms
# Speed: 3.4ms preprocess, 135.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 795.1ms
# Speed: 2.7ms preprocess, 795.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 138.3ms
# Speed: 2.8ms preprocess, 138.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 713.1ms
# Speed: 2.9ms preprocess, 713.1ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 90.0ms
# Speed: 2.8ms preprocess, 90.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 517.8ms
# Speed: 4.9ms preprocess, 517.8ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 86.1ms
# Speed: 2.8ms preprocess, 86.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 510.6ms
# Speed: 2.8ms preprocess, 510.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 114.4ms
# Speed: 3.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 525.1ms
# Speed: 7.7ms preprocess, 525.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 88.2ms
# Speed: 3.5ms preprocess, 88.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 535.3ms
# Speed: 4.5ms preprocess, 535.3ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 89.8ms
# Speed: 2.6ms preprocess, 89.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 523.6ms
# Speed: 2.8ms preprocess, 523.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 88.1ms
# Speed: 3.4ms preprocess, 88.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 heads, 532.9ms
# Speed: 9.7ms preprocess, 532.9ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 87.8ms
# Speed: 2.8ms preprocess, 87.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 515.4ms
# Speed: 2.6ms preprocess, 515.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 129.7ms
# Speed: 3.5ms preprocess, 129.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 512.4ms
# Speed: 7.9ms preprocess, 512.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 93.8ms
# Speed: 2.7ms preprocess, 93.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 518.2ms
# Speed: 3.1ms preprocess, 518.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 89.8ms
# Speed: 2.6ms preprocess, 89.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 523.7ms
# Speed: 2.8ms preprocess, 523.7ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 85.4ms
# Speed: 4.7ms preprocess, 85.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 525.0ms
# Speed: 6.7ms preprocess, 525.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 87.1ms
# Speed: 2.6ms preprocess, 87.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 811.9ms
# Speed: 3.5ms preprocess, 811.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 130.1ms
# Speed: 2.6ms preprocess, 130.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 825.4ms
# Speed: 13.3ms preprocess, 825.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 141.6ms
# Speed: 2.7ms preprocess, 141.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 526.2ms
# Speed: 2.9ms preprocess, 526.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 92.7ms
# Speed: 2.9ms preprocess, 92.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 530.8ms
# Speed: 2.7ms preprocess, 530.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 86.5ms
# Speed: 2.8ms preprocess, 86.5ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 492.0ms
# Speed: 2.6ms preprocess, 492.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 90.6ms
# Speed: 2.7ms preprocess, 90.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 518.2ms
# Speed: 3.8ms preprocess, 518.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 88.1ms
# Speed: 2.6ms preprocess, 88.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 526.8ms
# Speed: 5.8ms preprocess, 526.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 89.2ms
# Speed: 2.6ms preprocess, 89.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 heads, 531.4ms
# Speed: 3.9ms preprocess, 531.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 91.7ms
# Speed: 2.6ms preprocess, 91.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 522.3ms
# Speed: 2.9ms preprocess, 522.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 91.2ms
# Speed: 3.0ms preprocess, 91.2ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 519.8ms
# Speed: 2.6ms preprocess, 519.8ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 89.9ms
# Speed: 3.2ms preprocess, 89.9ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 531.6ms
# Speed: 3.0ms preprocess, 531.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 89.2ms
# Speed: 2.5ms preprocess, 89.2ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 552.9ms
# Speed: 2.7ms preprocess, 552.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 89.7ms
# Speed: 3.3ms preprocess, 89.7ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 516.1ms
# Speed: 8.8ms preprocess, 516.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 101.8ms
# Speed: 3.1ms preprocess, 101.8ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 524.1ms
# Speed: 2.9ms preprocess, 524.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 86.6ms
# Speed: 3.1ms preprocess, 86.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 552.6ms
# Speed: 2.9ms preprocess, 552.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 135.8ms
# Speed: 2.8ms preprocess, 135.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 797.1ms
# Speed: 2.9ms preprocess, 797.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 132.8ms
# Speed: 3.1ms preprocess, 132.8ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 770.4ms
# Speed: 6.0ms preprocess, 770.4ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 116.2ms
# Speed: 2.5ms preprocess, 116.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 516.5ms
# Speed: 10.3ms preprocess, 516.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 103.4ms
# Speed: 2.6ms preprocess, 103.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 516.8ms
# Speed: 2.6ms preprocess, 516.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 87.7ms
# Speed: 2.9ms preprocess, 87.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 519.8ms
# Speed: 2.8ms preprocess, 519.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 87.8ms
# Speed: 3.0ms preprocess, 87.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 heads, 514.0ms
# Speed: 2.7ms preprocess, 514.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 87.9ms
# Speed: 3.7ms preprocess, 87.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 535.0ms
# Speed: 3.1ms preprocess, 535.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 112.4ms
# Speed: 2.6ms preprocess, 112.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 535.8ms
# Speed: 4.1ms preprocess, 535.8ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 90.0ms
# Speed: 2.7ms preprocess, 90.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 526.4ms
# Speed: 4.2ms preprocess, 526.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 85.8ms
# Speed: 3.0ms preprocess, 85.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 507.0ms
# Speed: 2.8ms preprocess, 507.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 89.4ms
# Speed: 2.7ms preprocess, 89.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 515.6ms
# Speed: 2.6ms preprocess, 515.6ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.7ms
# Speed: 3.8ms preprocess, 88.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 heads, 536.6ms
# Speed: 3.4ms preprocess, 536.6ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 116.2ms
# Speed: 2.5ms preprocess, 116.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 heads, 523.9ms
# Speed: 2.9ms preprocess, 523.9ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 89.9ms
# Speed: 2.9ms preprocess, 89.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 791.7ms
# Speed: 3.1ms preprocess, 791.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 131.5ms
# Speed: 2.7ms preprocess, 131.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 head, 790.5ms
# Speed: 2.8ms preprocess, 790.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 147.9ms
# Speed: 2.7ms preprocess, 147.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
# ✅  Saved /content/output_videos/tracked_11.mp4
# ▶️  Processing 12.mp4
#
# 0: 288x512 (no detections), 654.1ms
# Speed: 3.2ms preprocess, 654.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 90.1ms
# Speed: 2.6ms preprocess, 90.1ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 497.5ms
# Speed: 2.6ms preprocess, 497.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 127.1ms
# Speed: 2.8ms preprocess, 127.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 487.8ms
# Speed: 3.0ms preprocess, 487.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 86.1ms
# Speed: 2.6ms preprocess, 86.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 505.1ms
# Speed: 2.5ms preprocess, 505.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 88.0ms
# Speed: 2.5ms preprocess, 88.0ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 480.3ms
# Speed: 2.8ms preprocess, 480.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 89.1ms
# Speed: 3.3ms preprocess, 89.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 502.0ms
# Speed: 4.2ms preprocess, 502.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 86.1ms
# Speed: 3.8ms preprocess, 86.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 488.2ms
# Speed: 3.0ms preprocess, 488.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 120.0ms
# Speed: 2.5ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 483.8ms
# Speed: 2.6ms preprocess, 483.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 85.3ms
# Speed: 2.8ms preprocess, 85.3ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 500.5ms
# Speed: 3.0ms preprocess, 500.5ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 87.8ms
# Speed: 2.8ms preprocess, 87.8ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 492.8ms
# Speed: 2.8ms preprocess, 492.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 91.3ms
# Speed: 2.7ms preprocess, 91.3ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 124 heads, 499.3ms
# Speed: 2.6ms preprocess, 499.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.3ms
# Speed: 2.5ms preprocess, 88.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 124 heads, 800.6ms
# Speed: 2.9ms preprocess, 800.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 161.4ms
# Speed: 2.7ms preprocess, 161.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 126 heads, 513.5ms
# Speed: 3.7ms preprocess, 513.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 86.7ms
# Speed: 2.6ms preprocess, 86.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 623.0ms
# Speed: 2.8ms preprocess, 623.0ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 sports ball, 138.0ms
# Speed: 2.6ms preprocess, 138.0ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 112 heads, 527.7ms
# Speed: 2.9ms preprocess, 527.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 89.2ms
# Speed: 2.8ms preprocess, 89.2ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 116 heads, 520.0ms
# Speed: 2.9ms preprocess, 520.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 sports ball, 86.7ms
# Speed: 3.3ms preprocess, 86.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 109 heads, 514.5ms
# Speed: 2.9ms preprocess, 514.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 sports ball, 118.2ms
# Speed: 2.7ms preprocess, 118.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 526.2ms
# Speed: 10.9ms preprocess, 526.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 sports ball, 90.9ms
# Speed: 2.7ms preprocess, 90.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 109 heads, 672.9ms
# Speed: 3.5ms preprocess, 672.9ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 1 sports ball, 139.4ms
# Speed: 2.6ms preprocess, 139.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 111 heads, 515.1ms
# Speed: 2.8ms preprocess, 515.1ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 sports ball, 89.8ms
# Speed: 2.6ms preprocess, 89.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 523.1ms
# Speed: 2.9ms preprocess, 523.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 sports ball, 111.8ms
# Speed: 2.7ms preprocess, 111.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 520.0ms
# Speed: 2.8ms preprocess, 520.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 sports ball, 113.1ms
# Speed: 2.7ms preprocess, 113.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 104 heads, 512.0ms
# Speed: 2.9ms preprocess, 512.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 sports ball, 86.8ms
# Speed: 2.6ms preprocess, 86.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 104 heads, 527.4ms
# Speed: 10.1ms preprocess, 527.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 sports ball, 90.0ms
# Speed: 2.7ms preprocess, 90.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 110 heads, 517.2ms
# Speed: 3.0ms preprocess, 517.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 sports ball, 83.8ms
# Speed: 2.9ms preprocess, 83.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 117 heads, 521.4ms
# Speed: 3.0ms preprocess, 521.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 sports ball, 84.4ms
# Speed: 3.9ms preprocess, 84.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 123 heads, 570.0ms
# Speed: 3.6ms preprocess, 570.0ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 sports ball, 93.3ms
# Speed: 2.8ms preprocess, 93.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 524.3ms
# Speed: 2.9ms preprocess, 524.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 sports ball, 88.8ms
# Speed: 2.9ms preprocess, 88.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 113 heads, 793.0ms
# Speed: 2.8ms preprocess, 793.0ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 sports ball, 135.4ms
# Speed: 2.8ms preprocess, 135.4ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 113 heads, 537.1ms
# Speed: 3.0ms preprocess, 537.1ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 sports ball, 87.8ms
# Speed: 3.2ms preprocess, 87.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 114 heads, 525.6ms
# Speed: 10.4ms preprocess, 525.6ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 1 sports ball, 89.9ms
# Speed: 2.8ms preprocess, 89.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 119 heads, 513.8ms
# Speed: 4.2ms preprocess, 513.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 1 sports ball, 90.8ms
# Speed: 2.5ms preprocess, 90.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 548.8ms
# Speed: 2.8ms preprocess, 548.8ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 92.3ms
# Speed: 2.7ms preprocess, 92.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 120 heads, 612.0ms
# Speed: 2.9ms preprocess, 612.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 107.1ms
# Speed: 2.8ms preprocess, 107.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 119 heads, 504.0ms
# Speed: 3.6ms preprocess, 504.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 101.9ms
# Speed: 2.7ms preprocess, 101.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 120 heads, 808.4ms
# Speed: 2.9ms preprocess, 808.4ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 130.3ms
# Speed: 2.8ms preprocess, 130.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 122 heads, 506.0ms
# Speed: 3.0ms preprocess, 506.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 87.0ms
# Speed: 3.1ms preprocess, 87.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 129 heads, 509.9ms
# Speed: 4.1ms preprocess, 509.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 5 persons, 88.0ms
# Speed: 2.9ms preprocess, 88.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 132 heads, 508.1ms
# Speed: 2.9ms preprocess, 508.1ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 87.4ms
# Speed: 2.8ms preprocess, 87.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 120 heads, 504.6ms
# Speed: 3.3ms preprocess, 504.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 102.4ms
# Speed: 2.6ms preprocess, 102.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 122 heads, 529.3ms
# Speed: 3.0ms preprocess, 529.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 90.9ms
# Speed: 3.5ms preprocess, 90.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 124 heads, 514.7ms
# Speed: 7.5ms preprocess, 514.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 88.7ms
# Speed: 3.0ms preprocess, 88.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 519.8ms
# Speed: 2.9ms preprocess, 519.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 89.2ms
# Speed: 3.0ms preprocess, 89.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 129 heads, 505.4ms
# Speed: 2.9ms preprocess, 505.4ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 95.5ms
# Speed: 2.7ms preprocess, 95.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 119 heads, 732.3ms
# Speed: 4.0ms preprocess, 732.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 87.6ms
# Speed: 2.6ms preprocess, 87.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 122 heads, 520.5ms
# Speed: 10.2ms preprocess, 520.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 95.0ms
# Speed: 2.6ms preprocess, 95.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 786.4ms
# Speed: 3.0ms preprocess, 786.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 130.2ms
# Speed: 2.7ms preprocess, 130.2ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 110 heads, 535.9ms
# Speed: 3.2ms preprocess, 535.9ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 94.7ms
# Speed: 2.8ms preprocess, 94.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 101 heads, 526.7ms
# Speed: 3.1ms preprocess, 526.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 86.0ms
# Speed: 3.3ms preprocess, 86.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 106 heads, 505.3ms
# Speed: 4.7ms preprocess, 505.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 89.1ms
# Speed: 2.9ms preprocess, 89.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 111 heads, 528.4ms
# Speed: 3.0ms preprocess, 528.4ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 86.9ms
# Speed: 2.6ms preprocess, 86.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 117 heads, 796.4ms
# Speed: 5.2ms preprocess, 796.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 135.5ms
# Speed: 2.7ms preprocess, 135.5ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 114 heads, 533.1ms
# Speed: 14.9ms preprocess, 533.1ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 86.3ms
# Speed: 2.9ms preprocess, 86.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 113 heads, 517.0ms
# Speed: 3.1ms preprocess, 517.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 87.0ms
# Speed: 2.9ms preprocess, 87.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 104 heads, 508.5ms
# Speed: 3.0ms preprocess, 508.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 92.4ms
# Speed: 2.6ms preprocess, 92.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 99 heads, 498.2ms
# Speed: 3.1ms preprocess, 498.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 85.4ms
# Speed: 3.0ms preprocess, 85.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 104 heads, 757.3ms
# Speed: 2.8ms preprocess, 757.3ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 147.1ms
# Speed: 2.6ms preprocess, 147.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 100 heads, 512.0ms
# Speed: 3.0ms preprocess, 512.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 87.0ms
# Speed: 2.8ms preprocess, 87.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 97 heads, 491.2ms
# Speed: 8.3ms preprocess, 491.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 89.0ms
# Speed: 3.2ms preprocess, 89.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 98 heads, 503.5ms
# Speed: 3.0ms preprocess, 503.5ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 88.3ms
# Speed: 2.8ms preprocess, 88.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 98 heads, 502.7ms
# Speed: 4.0ms preprocess, 502.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 89.7ms
# Speed: 2.9ms preprocess, 89.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 102 heads, 491.5ms
# Speed: 10.1ms preprocess, 491.5ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 89.2ms
# Speed: 3.0ms preprocess, 89.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 102 heads, 508.0ms
# Speed: 3.8ms preprocess, 508.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 persons, 86.0ms
# Speed: 2.9ms preprocess, 86.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 104 heads, 508.9ms
# Speed: 2.9ms preprocess, 508.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 94.5ms
# Speed: 5.5ms preprocess, 94.5ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 109 heads, 801.0ms
# Speed: 3.5ms preprocess, 801.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 87.2ms
# Speed: 3.1ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 516.8ms
# Speed: 3.6ms preprocess, 516.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 86.2ms
# Speed: 2.9ms preprocess, 86.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 106 heads, 513.6ms
# Speed: 2.9ms preprocess, 513.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 persons, 87.4ms
# Speed: 3.6ms preprocess, 87.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 121 heads, 532.8ms
# Speed: 5.4ms preprocess, 532.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 persons, 89.3ms
# Speed: 2.7ms preprocess, 89.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
# ✅  Saved /content/output_videos/tracked_12.mp4
# ▶️  Processing 13.mp4
#
# 0: 288x512 105 heads, 500.8ms
# Speed: 2.9ms preprocess, 500.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 12 persons, 90.0ms
# Speed: 2.7ms preprocess, 90.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 100 heads, 514.5ms
# Speed: 5.3ms preprocess, 514.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 13 persons, 87.0ms
# Speed: 2.9ms preprocess, 87.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 103 heads, 503.4ms
# Speed: 2.9ms preprocess, 503.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 99.8ms
# Speed: 3.0ms preprocess, 99.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 102 heads, 795.9ms
# Speed: 2.9ms preprocess, 795.9ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 123.7ms
# Speed: 2.7ms preprocess, 123.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 110 heads, 529.6ms
# Speed: 3.0ms preprocess, 529.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 114.6ms
# Speed: 3.2ms preprocess, 114.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 100 heads, 525.1ms
# Speed: 2.7ms preprocess, 525.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 87.8ms
# Speed: 2.5ms preprocess, 87.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 114 heads, 505.9ms
# Speed: 4.1ms preprocess, 505.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 88.0ms
# Speed: 2.8ms preprocess, 88.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 509.8ms
# Speed: 2.9ms preprocess, 509.8ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 86.1ms
# Speed: 3.3ms preprocess, 86.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 519.4ms
# Speed: 4.6ms preprocess, 519.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 88.7ms
# Speed: 2.9ms preprocess, 88.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 524.3ms
# Speed: 2.9ms preprocess, 524.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 89.3ms
# Speed: 2.8ms preprocess, 89.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 113 heads, 622.2ms
# Speed: 2.9ms preprocess, 622.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 125.6ms
# Speed: 2.5ms preprocess, 125.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 114 heads, 506.7ms
# Speed: 4.4ms preprocess, 506.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 87.7ms
# Speed: 3.5ms preprocess, 87.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 119 heads, 795.1ms
# Speed: 10.3ms preprocess, 795.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 145.7ms
# Speed: 2.9ms preprocess, 145.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 117 heads, 522.6ms
# Speed: 4.0ms preprocess, 522.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 86.6ms
# Speed: 2.7ms preprocess, 86.6ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 114 heads, 728.1ms
# Speed: 2.9ms preprocess, 728.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 141.6ms
# Speed: 2.8ms preprocess, 141.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 524.3ms
# Speed: 7.3ms preprocess, 524.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 88.7ms
# Speed: 2.9ms preprocess, 88.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 116 heads, 515.7ms
# Speed: 2.8ms preprocess, 515.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 85.5ms
# Speed: 2.9ms preprocess, 85.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 115 heads, 509.7ms
# Speed: 9.8ms preprocess, 509.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 persons, 86.4ms
# Speed: 2.8ms preprocess, 86.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 116 heads, 513.8ms
# Speed: 2.9ms preprocess, 513.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 106 heads, 523.1ms
# Speed: 11.0ms preprocess, 523.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 persons, 113.9ms
# Speed: 2.5ms preprocess, 113.9ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 529.6ms
# Speed: 4.4ms preprocess, 529.6ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 87.1ms
# Speed: 2.8ms preprocess, 87.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 785.1ms
# Speed: 6.6ms preprocess, 785.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 138.4ms
# Speed: 2.7ms preprocess, 138.4ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 117 heads, 521.0ms
# Speed: 3.0ms preprocess, 521.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 89.2ms
# Speed: 2.5ms preprocess, 89.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 108 heads, 521.2ms
# Speed: 4.1ms preprocess, 521.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 86.2ms
# Speed: 5.5ms preprocess, 86.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 99 heads, 526.7ms
# Speed: 3.0ms preprocess, 526.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 persons, 111.2ms
# Speed: 3.0ms preprocess, 111.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 93 heads, 508.8ms
# Speed: 3.1ms preprocess, 508.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 102.0ms
# Speed: 2.9ms preprocess, 102.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 84 heads, 622.4ms
# Speed: 12.0ms preprocess, 622.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 87.3ms
# Speed: 2.8ms preprocess, 87.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 87 heads, 518.0ms
# Speed: 2.8ms preprocess, 518.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 persons, 104.6ms
# Speed: 2.8ms preprocess, 104.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 90 heads, 509.1ms
# Speed: 3.1ms preprocess, 509.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 94.6ms
# Speed: 2.9ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 93 heads, 500.8ms
# Speed: 11.2ms preprocess, 500.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 124.8ms
# Speed: 2.6ms preprocess, 124.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 102 heads, 501.9ms
# Speed: 2.9ms preprocess, 501.9ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 persons, 85.8ms
# Speed: 2.8ms preprocess, 85.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 100 heads, 524.8ms
# Speed: 3.9ms preprocess, 524.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 persons, 124.1ms
# Speed: 2.8ms preprocess, 124.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 110 heads, 551.3ms
# Speed: 8.3ms preprocess, 551.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 12 persons, 89.9ms
# Speed: 2.9ms preprocess, 89.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 114 heads, 522.2ms
# ...
#
# 0: 288x512 1 umbrella, 89.1ms
# Speed: 2.6ms preprocess, 89.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 21 heads, 517.8ms
# Speed: 2.6ms preprocess, 517.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 105.9ms
# Speed: 2.8ms preprocess, 105.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 25 heads, 792.8ms
# Speed: 5.6ms preprocess, 792.8ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 132.0ms
# Speed: 3.2ms preprocess, 132.0ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 20 heads, 519.9ms
# Speed: 3.6ms preprocess, 519.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 89.6ms
# Speed: 3.3ms preprocess, 89.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 13 heads, 518.2ms
# Speed: 2.8ms preprocess, 518.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 102.2ms
# Speed: 2.9ms preprocess, 102.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 15 heads, 526.7ms
# Speed: 2.8ms preprocess, 526.7ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 89.1ms
# Speed: 2.5ms preprocess, 89.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 15 heads, 518.6ms
# Speed: 5.0ms preprocess, 518.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 87.1ms
# Speed: 2.9ms preprocess, 87.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 17 heads, 523.5ms
# Speed: 3.2ms preprocess, 523.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 86.1ms
# Speed: 2.6ms preprocess, 86.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 17 heads, 510.3ms
# Speed: 7.7ms preprocess, 510.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 93.2ms
# Speed: 2.6ms preprocess, 93.2ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 15 heads, 507.3ms
# Speed: 2.9ms preprocess, 507.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 118.7ms
# Speed: 2.9ms preprocess, 118.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 heads, 525.6ms
# Speed: 2.9ms preprocess, 525.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 85.8ms
# Speed: 5.3ms preprocess, 85.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 heads, 789.7ms
# Speed: 2.9ms preprocess, 789.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 130.5ms
# Speed: 2.7ms preprocess, 130.5ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 heads, 791.7ms
# Speed: 2.8ms preprocess, 791.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 98.3ms
# Speed: 2.7ms preprocess, 98.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 heads, 517.9ms
# Speed: 3.4ms preprocess, 517.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 84.4ms
# Speed: 2.9ms preprocess, 84.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 7 heads, 509.1ms
# Speed: 7.7ms preprocess, 509.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 84.4ms
# Speed: 2.9ms preprocess, 84.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 heads, 515.6ms
# Speed: 5.9ms preprocess, 515.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 121.4ms
# Speed: 2.9ms preprocess, 121.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 heads, 508.4ms
# Speed: 2.9ms preprocess, 508.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 87.5ms
# Speed: 4.3ms preprocess, 87.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 14 heads, 519.3ms
# Speed: 5.2ms preprocess, 519.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 91.3ms
# Speed: 2.7ms preprocess, 91.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 14 heads, 518.1ms
# Speed: 2.9ms preprocess, 518.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 87.4ms
# Speed: 2.7ms preprocess, 87.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 17 heads, 518.2ms
# Speed: 9.6ms preprocess, 518.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 85.9ms
# Speed: 2.7ms preprocess, 85.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 21 heads, 517.6ms
# Speed: 2.7ms preprocess, 517.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 96.1ms
# Speed: 3.7ms preprocess, 96.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 18 heads, 537.0ms
# Speed: 8.1ms preprocess, 537.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 125.3ms
# Speed: 2.7ms preprocess, 125.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 16 heads, 819.4ms
# Speed: 4.7ms preprocess, 819.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 140.7ms
# Speed: 2.7ms preprocess, 140.7ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 19 heads, 521.7ms
# Speed: 2.7ms preprocess, 521.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 91.0ms
# Speed: 2.6ms preprocess, 91.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 21 heads, 522.6ms
# Speed: 3.4ms preprocess, 522.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 104.7ms
# Speed: 2.9ms preprocess, 104.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 20 heads, 541.4ms
# Speed: 3.5ms preprocess, 541.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 95.9ms
# Speed: 4.4ms preprocess, 95.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 20 heads, 517.3ms
# Speed: 3.6ms preprocess, 517.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 88.0ms
# Speed: 3.3ms preprocess, 88.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 26 heads, 535.3ms
# Speed: 2.8ms preprocess, 535.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 84.0ms
# Speed: 2.7ms preprocess, 84.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 28 heads, 515.4ms
# Speed: 2.7ms preprocess, 515.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 114.6ms
# Speed: 2.6ms preprocess, 114.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 22 heads, 530.6ms
# Speed: 4.7ms preprocess, 530.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 86.9ms
# Speed: 2.9ms preprocess, 86.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 21 heads, 832.6ms
# Speed: 2.8ms preprocess, 832.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 125.1ms
# Speed: 2.6ms preprocess, 125.1ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 26 heads, 524.6ms
# Speed: 3.0ms preprocess, 524.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 89.4ms
# Speed: 3.0ms preprocess, 89.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 21 heads, 529.0ms
# Speed: 3.0ms preprocess, 529.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 106.4ms
# Speed: 2.2ms preprocess, 106.4ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 23 heads, 523.6ms
# Speed: 10.7ms preprocess, 523.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 88.8ms
# Speed: 3.0ms preprocess, 88.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 29 heads, 535.7ms
# Speed: 3.2ms preprocess, 535.7ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 120.0ms
# Speed: 2.5ms preprocess, 120.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 31 heads, 519.1ms
# Speed: 3.6ms preprocess, 519.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 92.3ms
# Speed: 2.8ms preprocess, 92.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 31 heads, 513.5ms
# Speed: 3.7ms preprocess, 513.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 88.9ms
# Speed: 2.6ms preprocess, 88.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 30 heads, 812.3ms
# Speed: 8.4ms preprocess, 812.3ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 131.6ms
# Speed: 2.8ms preprocess, 131.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 23 heads, 510.5ms
# Speed: 5.0ms preprocess, 510.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 88.9ms
# Speed: 2.7ms preprocess, 88.9ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 23 heads, 532.9ms
# Speed: 4.8ms preprocess, 532.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 89.7ms
# Speed: 2.7ms preprocess, 89.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 21 heads, 559.5ms
# Speed: 7.9ms preprocess, 559.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 88.4ms
# Speed: 2.5ms preprocess, 88.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 14 heads, 519.4ms
# Speed: 2.7ms preprocess, 519.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 100.3ms
# Speed: 2.8ms preprocess, 100.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 heads, 529.7ms
# Speed: 2.9ms preprocess, 529.7ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 88.8ms
# Speed: 2.8ms preprocess, 88.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 12 heads, 531.2ms
# Speed: 2.9ms preprocess, 531.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 86.4ms
# Speed: 2.9ms preprocess, 86.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 heads, 526.7ms
# Speed: 9.5ms preprocess, 526.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 94.7ms
# Speed: 3.2ms preprocess, 94.7ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 9 heads, 523.4ms
# Speed: 2.6ms preprocess, 523.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 120.6ms
# Speed: 2.7ms preprocess, 120.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 11 heads, 803.7ms
# Speed: 2.6ms preprocess, 803.7ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 150.9ms
# Speed: 2.9ms preprocess, 150.9ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 8 heads, 810.2ms
# Speed: 2.6ms preprocess, 810.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 87.9ms
# Speed: 2.8ms preprocess, 87.9ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 6 heads, 522.4ms
# Speed: 9.6ms preprocess, 522.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 90.8ms
# Speed: 2.9ms preprocess, 90.8ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 10 heads, 505.2ms
# Speed: 2.9ms preprocess, 505.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 96.1ms
# Speed: 3.0ms preprocess, 96.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 14 heads, 513.5ms
# Speed: 9.5ms preprocess, 513.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 86.5ms
# Speed: 2.9ms preprocess, 86.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 24 heads, 550.6ms
# Speed: 4.3ms preprocess, 550.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 86.7ms
# Speed: 2.7ms preprocess, 86.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 24 heads, 511.2ms
# Speed: 2.9ms preprocess, 511.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 90.5ms
# Speed: 3.6ms preprocess, 90.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 24 heads, 528.0ms
# Speed: 2.9ms preprocess, 528.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 102.7ms
# Speed: 2.7ms preprocess, 102.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 24 heads, 518.8ms
# Speed: 7.3ms preprocess, 518.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 87.7ms
# Speed: 2.9ms preprocess, 87.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 28 heads, 746.6ms
# Speed: 8.5ms preprocess, 746.6ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 130.5ms
# Speed: 2.6ms preprocess, 130.5ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 31 heads, 666.6ms
# Speed: 2.9ms preprocess, 666.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 person, 1 umbrella, 118.1ms
# Speed: 4.3ms preprocess, 118.1ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 26 heads, 524.2ms
# Speed: 2.4ms preprocess, 524.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 90.8ms
# Speed: 3.0ms preprocess, 90.8ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 25 heads, 531.3ms
# Speed: 4.7ms preprocess, 531.3ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 87.6ms
# Speed: 2.8ms preprocess, 87.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 24 heads, 523.4ms
# Speed: 2.8ms preprocess, 523.4ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 89.1ms
# Speed: 2.6ms preprocess, 89.1ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 24 heads, 517.1ms
# Speed: 3.0ms preprocess, 517.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 89.6ms
# Speed: 2.8ms preprocess, 89.6ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 25 heads, 521.9ms
# Speed: 3.2ms preprocess, 521.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 umbrella, 89.5ms
# Speed: 2.8ms preprocess, 89.5ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
# ✅  Saved /content/output_videos/tracked_20.mp4
# 🎉  Done! Log saved at /content/output_videos/tracking_log.csv

# %%
import os
import pandas as pd
import numpy as np
import cv2
from collections import defaultdict, deque

# ─── Config ───────────────────────────────────────────────────────────────────
video_folder = "./videos"  # Folder with 01.mp4 → 20.mp4
csv_path     = "./output_videos/tracking_log.csv"
out_folder   = "./heatmap_flow_vectors"
os.makedirs(out_folder, exist_ok=True)

FLOW_MEMORY = 5          # Number of past frames to average flow over
MOTION_THRESH = 2        # Minimum movement in pixels to be considered valid flow
VECTOR_LIFE = 10         # How many frames a vector should persist on screen
FLOW_SCALE = 0.4         # Reduce motion vector length (for smoother look)

# ─── Load Data ────────────────────────────────────────────────────────────────
df_all = pd.read_csv(csv_path)

# ─── Process Videos ───────────────────────────────────────────────────────────
for i in range(1, 21):  # Change range as needed
    vid_name = f"{i:02}.mp4"
    in_path  = os.path.join(video_folder, vid_name)
    out_path = os.path.join(out_folder, f"heatmap_flow_{vid_name}")

    if not os.path.isfile(in_path):
        print(f"  Skipping missing video: {vid_name}")
        continue

    df = df_all[df_all["video"] == vid_name].copy()
    if df.empty:
        print(f"  No bounding boxes for: {vid_name}")
        continue

    cap = cv2.VideoCapture(in_path)
    if not cap.isOpened():
        print(f" Error: Cannot open video {vid_name}")
        continue

    fps     = int(cap.get(cv2.CAP_PROP_FPS))
    width   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height  = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

    heatmap = np.zeros((height, width), dtype=np.float32)
    track_history = defaultdict(deque)  # track_id → deque of (cx, cy)
    active_vectors = deque()  # persistent arrows

    frame_idx = 0
    print(f"  Processing {vid_name}...")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        df_frame = df[df["frame_id"] == frame_idx]
        flow_vectors = []

        for _, row in df_frame.iterrows():
            tid = int(row["track_id"])
            x1, y1, x2, y2 = int(row['x1']), int(row['y1']), int(row['x2']), int(row['y2'])
            x1, x2 = np.clip([x1, x2], 0, width - 1)
            y1, y2 = np.clip([y1, y2], 0, height - 1)

            if x2 > x1 and y2 > y1:
                heatmap[y1:y2, x1:x2] += 1

            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)

            history = track_history[tid]
            history.append((cx, cy))
            if len(history) > FLOW_MEMORY:
                history.popleft()

            if len(history) >= 2:
                x_coords, y_coords = zip(*history)
                x_avg = int(np.mean(x_coords))
                y_avg = int(np.mean(y_coords))

                dx = x_coords[-1] - x_coords[0]
                dy = y_coords[-1] - y_coords[0]
                dist = np.hypot(dx, dy)

                if dist >= MOTION_THRESH:
                    pt1 = (x_avg, y_avg)
                    pt2 = (int(x_avg + dx * FLOW_SCALE), int(y_avg + dy * FLOW_SCALE))
                    # Store (start, end, life, strength)
                    active_vectors.append((pt1, pt2, VECTOR_LIFE, dist))

        # ─── Smooth Heatmap ─────────────────────────────────────────────────────
        temp_heatmap = cv2.GaussianBlur(heatmap.copy(), (25, 25), 0)
        temp_heatmap = cv2.normalize(temp_heatmap, None, 0, 255, cv2.NORM_MINMAX)
        temp_heatmap = temp_heatmap.astype(np.uint8)
        color_heatmap = cv2.applyColorMap(temp_heatmap, cv2.COLORMAP_JET)
        overlay = cv2.addWeighted(frame, 0.5, color_heatmap, 0.5, 0)

        # ─── Draw Arrows ───────────────────────────────────────────────────────
        new_vectors = deque()
        for pt1, pt2, life, dist in active_vectors:
            if life > 0:
                fade = int(255 * (life / VECTOR_LIFE))  # Fade effect
                color = (fade, fade, fade)  # White to gray
                thickness = 1
                cv2.arrowedLine(overlay, pt1, pt2, color, thickness, tipLength=0.3)
                new_vectors.append((pt1, pt2, life - 1, dist))
        active_vectors = new_vectors

        out.write(overlay)
        frame_idx += 1

    cap.release()
    out.release()
    print(f" Saved: {out_path}")

print(" All enhanced heatmap + clean flow videos created.")
# Out:
# ▶️  Processing 01.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_01.mp4
# ▶️  Processing 02.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_02.mp4
# ▶️  Processing 03.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_03.mp4
# ▶️  Processing 04.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_04.mp4
# ▶️  Processing 05.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_05.mp4
# ▶️  Processing 06.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_06.mp4
# ▶️  Processing 07.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_07.mp4
# ▶️  Processing 08.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_08.mp4
# ▶️  Processing 09.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_09.mp4
# ▶️  Processing 10.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_10.mp4
# ▶️  Processing 11.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_11.mp4
# ▶️  Processing 12.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_12.mp4
# ▶️  Processing 13.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_13.mp4
# ▶️  Processing 14.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_14.mp4
# ▶️  Processing 15.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_15.mp4
# ▶️  Processing 16.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_16.mp4
# ▶️  Processing 17.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_17.mp4
# ▶️  Processing 18.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_18.mp4
# ▶️  Processing 19.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_19.mp4
# ▶️  Processing 20.mp4...
# ✅ Saved: /content/heatmap_flow_vectors/heatmap_flow_20.mp4
# 🎉 All enhanced heatmap + clean flow videos created.

# %%
#plot trajectories
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import os

# === CONFIGURATION ===
csv_path = './output_videos/tracking_log.csv'
video_dir = './videos'     # Folder where videos are located
output_dir = './trajectory_outputs'  # Folder to save plots and CSVs
video_prefix = ''
video_ext = '.mp4'
frame_stride = 10
movement_threshold = 30  # pixels
max_videos = 20
# =======================

# Create output directory
os.makedirs(output_dir, exist_ok=True)

# Load tracking data
df = pd.read_csv(csv_path)

if 'video' not in df.columns:
    raise ValueError("CSV must contain a 'video' column for this to work on multiple videos.")

# Compute centers
df['cx'] = (df['x1'] + df['x2']) / 2
df['cy'] = (df['y1'] + df['y2']) / 2

# Function: Determine direction of movement
def get_direction(x0, y0, x1, y1):
    dx, dy = x1 - x0, y1 - y0
    angle = np.degrees(np.arctan2(-dy, dx)) % 360
    if 337.5 <= angle or angle < 22.5:
        return 'E'
    elif 22.5 <= angle < 67.5:
        return 'NE'
    elif 67.5 <= angle < 112.5:
        return 'N'
    elif 112.5 <= angle < 157.5:
        return 'NW'
    elif 157.5 <= angle < 202.5:
        return 'W'
    elif 202.5 <= angle < 247.5:
        return 'SW'
    elif 247.5 <= angle < 292.5:
        return 'S'
    elif 292.5 <= angle < 337.5:
        return 'SE'
    return None

# Process each video
for vid_num in range(1, max_videos + 1):
    vid_name = f'{video_prefix}{vid_num:02d}{video_ext}'
    print(f'\n Processing: {vid_name}')

    vid_df = df[df['video'] == vid_name]

    if vid_df.empty:
        print(f"  No tracking data found for {vid_name}, skipping.")
        continue

    direction_buckets = {
        'N': [], 'NE': [], 'E': [], 'SE': [],
        'S': [], 'SW': [], 'W': [], 'NW': []
    }

    final_csv_rows = []
    selected_trajectories = {}

    for track_id in vid_df['track_id'].dropna().unique():
        group = vid_df[vid_df['track_id'] == track_id].sort_values('frame_id')
        sparse_group = group[group['frame_id'] % frame_stride == 0]

        if len(sparse_group) < 2:
            continue

        coords = sparse_group[['cx', 'cy']].values
        dist = np.sum(np.linalg.norm(coords[1:] - coords[:-1], axis=1))

        if dist < movement_threshold:
            continue

        direction = get_direction(coords[0][0], coords[0][1], coords[-1][0], coords[-1][1])
        if direction:
            direction_buckets[direction].append((track_id, coords, sparse_group))

    for direction, candidates in direction_buckets.items():
        if not candidates:
            continue
        # Choose the longest distance track
        selected = max(candidates, key=lambda x: np.sum(np.linalg.norm(x[1][1:] - x[1][:-1], axis=1)))
        track_id, coords, sparse_group = selected
        selected_trajectories[track_id] = coords
        final_csv_rows.append(sparse_group)

    if not selected_trajectories:
        print(f"  No qualifying trajectories found for {vid_name}")
        continue

    # Save sparse CSV
    sparse_csv_path = os.path.join(output_dir, f'trajectory_{vid_num:02d}.csv')
    pd.concat(final_csv_rows)[['frame_id', 'track_id', 'cx', 'cy']].to_csv(sparse_csv_path, index=False)

    # Plot
    plt.figure(figsize=(10, 8))
    for track_id, points in selected_trajectories.items():
        xs, ys = points[:, 0], points[:, 1]
        plt.plot(xs, ys, label=f'ID {track_id}')
        plt.scatter(xs[-1], ys[-1], s=10)
    plt.title(f'Trajectories in {vid_name}')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().invert_yaxis()
    plt.grid(True)
    plt.legend(loc='upper right', fontsize='x-small')
    plot_path = os.path.join(output_dir, f'trajectory_{vid_num:02d}.png')
    plt.savefig(plot_path)
    plt.close()

    print(f" Saved plot: {plot_path}")
    print(f" Saved CSV: {sparse_csv_path}")
# Out:
#  Processing: 01.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_01.png
#  Saved CSV: /content/trajectory_outputs/trajectory_01.csv
#
#  Processing: 02.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_02.png
#  Saved CSV: /content/trajectory_outputs/trajectory_02.csv
#
#  Processing: 03.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_03.png
#  Saved CSV: /content/trajectory_outputs/trajectory_03.csv
#
#  Processing: 04.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_04.png
#  Saved CSV: /content/trajectory_outputs/trajectory_04.csv
#
#  Processing: 05.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_05.png
#  Saved CSV: /content/trajectory_outputs/trajectory_05.csv
#
#  Processing: 06.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_06.png
#  Saved CSV: /content/trajectory_outputs/trajectory_06.csv
#
#  Processing: 07.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_07.png
#  Saved CSV: /content/trajectory_outputs/trajectory_07.csv
#
#  Processing: 08.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_08.png
#  Saved CSV: /content/trajectory_outputs/trajectory_08.csv
#
#  Processing: 09.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_09.png
#  Saved CSV: /content/trajectory_outputs/trajectory_09.csv
#
#  Processing: 10.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_10.png
#  Saved CSV: /content/trajectory_outputs/trajectory_10.csv
#
#  Processing: 11.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_11.png
#  Saved CSV: /content/trajectory_outputs/trajectory_11.csv
#
#  Processing: 12.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_12.png
#  Saved CSV: /content/trajectory_outputs/trajectory_12.csv
#
#  Processing: 13.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_13.png
#  Saved CSV: /content/trajectory_outputs/trajectory_13.csv
#
#  Processing: 14.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_14.png
#  Saved CSV: /content/trajectory_outputs/trajectory_14.csv
#
#  Processing: 15.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_15.png
#  Saved CSV: /content/trajectory_outputs/trajectory_15.csv
#
#  Processing: 16.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_16.png
#  Saved CSV: /content/trajectory_outputs/trajectory_16.csv
#
#  Processing: 17.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_17.png
#  Saved CSV: /content/trajectory_outputs/trajectory_17.csv
#
#  Processing: 18.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_18.png
#  Saved CSV: /content/trajectory_outputs/trajectory_18.csv
#
#  Processing: 19.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_19.png
#  Saved CSV: /content/trajectory_outputs/trajectory_19.csv
#
#  Processing: 20.mp4
#  Saved plot: /content/trajectory_outputs/trajectory_20.png
#  Saved CSV: /content/trajectory_outputs/trajectory_20.csv

# %%
#panic simulation
import cv2
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# ==== CONFIG ====
video_folder = './videos'
csv_path = './output_videos/tracking_log.csv'
output_folder = './panic_output_videos'
csv_output_path = './panic_simulation_output.csv'

panic_start_frame = 10
initial_panic_shift = 30
velocity_multiplier = 3
# =================

os.makedirs(output_folder, exist_ok=True)
df = pd.read_csv(csv_path)

# Ensure consistent column names
df.columns = [col.strip().lower() for col in df.columns]

# Final output records
output_records = []

# Loop through all 20 videos
for vid_num in range(1, 21):
    video_filename = f"{vid_num:02d}.mp4"
    video_path = os.path.join(video_folder, video_filename)
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f" Couldn't open video {video_filename}")
        continue

    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    out_path = os.path.join(output_folder, f"panic_{video_filename}")
    out = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

    frame_id = 0
    print(f" Processing video {video_filename}")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        new_frame = frame.copy()
        frame_data = df[(df['video'] == video_filename) & (df['frame_id'] == frame_id)]

        for _, row in frame_data.iterrows():
            if pd.isnull(row[['x1', 'y1', 'x2', 'y2']]).any():
                continue

            x1, y1, x2, y2 = map(int, [row['x1'], row['y1'], row['x2'], row['y2']])
            w, h = x2 - x1, y2 - y1
            if w <= 0 or h <= 0 or x1 < 0 or y1 < 0 or x2 > width or y2 > height:
                continue

            person_patch = frame[y1:y2, x1:x2]

            if frame_id >= panic_start_frame:
                frame_panic_intensity = frame_id - panic_start_frame + 1
                shift = initial_panic_shift + frame_panic_intensity * velocity_multiplier
                jitter = np.random.randint(-5, 6)
                new_x1 = min(width - w, x1 + shift + jitter)
            else:
                new_x1 = x1

            new_x2 = new_x1 + w
            if new_x1 < 0 or new_x2 > width:
                continue

            new_frame[y1:y2, new_x1:new_x2] = person_patch

            # Store updated row
            output_records.append([
                video_filename, frame_id, row['track_id'], new_x1, new_x2, y1, y2
            ])

        out.write(new_frame)
        frame_id += 1

    cap.release()
    out.release()
    print(f" Done: panic_{video_filename}")

# Save final output CSV
columns = ['video', 'frame_id', 'track_id', 'x1', 'x2', 'y1', 'y2']
output_df = pd.DataFrame(output_records, columns=columns)
output_df.to_csv(csv_output_path, index=False)
print(f" CSV saved to {csv_output_path}")
# Out:
# 🚀 Processing video 01.mp4
# ✅ Done: panic_01.mp4
# 🚀 Processing video 02.mp4
# ✅ Done: panic_02.mp4
# 🚀 Processing video 03.mp4
# ✅ Done: panic_03.mp4
# 🚀 Processing video 04.mp4
# ✅ Done: panic_04.mp4
# 🚀 Processing video 05.mp4
# ✅ Done: panic_05.mp4
# 🚀 Processing video 06.mp4
# ✅ Done: panic_06.mp4
# 🚀 Processing video 07.mp4
# ✅ Done: panic_07.mp4
# 🚀 Processing video 08.mp4
# ✅ Done: panic_08.mp4
# 🚀 Processing video 09.mp4
# ✅ Done: panic_09.mp4
# 🚀 Processing video 10.mp4
# ✅ Done: panic_10.mp4
# 🚀 Processing video 11.mp4
# ✅ Done: panic_11.mp4
# 🚀 Processing video 12.mp4
# ✅ Done: panic_12.mp4
# 🚀 Processing video 13.mp4
# ✅ Done: panic_13.mp4
# 🚀 Processing video 14.mp4
# ✅ Done: panic_14.mp4
# 🚀 Processing video 15.mp4
# ✅ Done: panic_15.mp4
# 🚀 Processing video 16.mp4
# ✅ Done: panic_16.mp4
# 🚀 Processing video 17.mp4
# ✅ Done: panic_17.mp4
# 🚀 Processing video 18.mp4
# ✅ Done: panic_18.mp4
# 🚀 Processing video 19.mp4
# ✅ Done: panic_19.mp4
# 🚀 Processing video 20.mp4
# ✅ Done: panic_20.mp4
# 📁 CSV saved to panic_simulation_output.csv

# %%
#heatmap for panic videos
import os
import pandas as pd
import numpy as np
import cv2
from collections import defaultdict, deque

# ─── Config ───────────────────────────────────────────────────────────────────
video_folder = "./panic_output_videos"  # Folder with 01.mp4 → 20.mp4
csv_path     = "./panic_simulation_output.csv"
out_folder   = "./panic_heatmap_flow_vectors"
os.makedirs(out_folder, exist_ok=True)

FLOW_MEMORY = 5          # Number of past frames to average flow over
MOTION_THRESH = 2        # Minimum movement in pixels to be considered valid flow
VECTOR_LIFE = 10         # How many frames a vector should persist on screen
FLOW_SCALE = 0.4         # Reduce motion vector length (for smoother look)

# ─── Load Data ────────────────────────────────────────────────────────────────
df_all = pd.read_csv(csv_path)

# ─── Process Videos ───────────────────────────────────────────────────────────
for i in range(1, 21):  # Change range as needed
    vid_name = f"panic_{i:02}.mp4"
    col_name = f"{i:02}.mp4"
    in_path  = os.path.join(video_folder, vid_name)
    out_path = os.path.join(out_folder, f"heatmap_flow_{vid_name}")

    if not os.path.isfile(in_path):
        print(f"  Skipping missing video: {vid_name}")
        continue

    df = df_all[df_all["video"] == col_name].copy()
    if df.empty:
        print(f"  No bounding boxes for: {vid_name}")
        continue

    cap = cv2.VideoCapture(in_path)
    if not cap.isOpened():
        print(f" Error: Cannot open video {vid_name}")
        continue

    fps     = int(cap.get(cv2.CAP_PROP_FPS))
    width   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height  = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

    heatmap = np.zeros((height, width), dtype=np.float32)
    track_history = defaultdict(deque)  # track_id → deque of (cx, cy)
    active_vectors = deque()  # persistent arrows

    frame_idx = 0
    print(f"  Processing {vid_name}...")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        df_frame = df[df["frame_id"] == frame_idx]
        flow_vectors = []

        for _, row in df_frame.iterrows():
            tid = int(row["track_id"])
            x1, y1, x2, y2 = int(row['x1']), int(row['y1']), int(row['x2']), int(row['y2'])
            x1, x2 = np.clip([x1, x2], 0, width - 1)
            y1, y2 = np.clip([y1, y2], 0, height - 1)

            if x2 > x1 and y2 > y1:
                heatmap[y1:y2, x1:x2] += 1

            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)

            history = track_history[tid]
            history.append((cx, cy))
            if len(history) > FLOW_MEMORY:
                history.popleft()

            if len(history) >= 2:
                x_coords, y_coords = zip(*history)
                x_avg = int(np.mean(x_coords))
                y_avg = int(np.mean(y_coords))

                dx = x_coords[-1] - x_coords[0]
                dy = y_coords[-1] - y_coords[0]
                dist = np.hypot(dx, dy)

                if dist >= MOTION_THRESH:
                    pt1 = (x_avg, y_avg)
                    pt2 = (int(x_avg + dx * FLOW_SCALE), int(y_avg + dy * FLOW_SCALE))
                    # Store (start, end, life, strength)
                    active_vectors.append((pt1, pt2, VECTOR_LIFE, dist))

        # ─── Smooth Heatmap ─────────────────────────────────────────────────────
        temp_heatmap = cv2.GaussianBlur(heatmap.copy(), (25, 25), 0)
        temp_heatmap = cv2.normalize(temp_heatmap, None, 0, 255, cv2.NORM_MINMAX)
        temp_heatmap = temp_heatmap.astype(np.uint8)
        color_heatmap = cv2.applyColorMap(temp_heatmap, cv2.COLORMAP_JET)
        overlay = cv2.addWeighted(frame, 0.5, color_heatmap, 0.5, 0)

        # ─── Draw Arrows ───────────────────────────────────────────────────────
        new_vectors = deque()
        for pt1, pt2, life, dist in active_vectors:
            if life > 0:
                fade = int(255 * (life / VECTOR_LIFE))  # Fade effect
                color = (fade, fade, fade)  # White to gray
                thickness = 1
                cv2.arrowedLine(overlay, pt1, pt2, color, thickness, tipLength=0.3)
                new_vectors.append((pt1, pt2, life - 1, dist))
        active_vectors = new_vectors

        out.write(overlay)
        frame_idx += 1

    cap.release()
    out.release()
    print(f" Saved: {out_path}")

print(" All enhanced heatmap + clean flow videos created.")
# Out:
# ▶️  Processing panic_01.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_01.mp4
# ▶️  Processing panic_02.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_02.mp4
# ▶️  Processing panic_03.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_03.mp4
# ▶️  Processing panic_04.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_04.mp4
# ▶️  Processing panic_05.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_05.mp4
# ▶️  Processing panic_06.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_06.mp4
# ▶️  Processing panic_07.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_07.mp4
# ▶️  Processing panic_08.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_08.mp4
# ▶️  Processing panic_09.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_09.mp4
# ▶️  Processing panic_10.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_10.mp4
# ▶️  Processing panic_11.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_11.mp4
# ▶️  Processing panic_12.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_12.mp4
# ▶️  Processing panic_13.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_13.mp4
# ▶️  Processing panic_14.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_14.mp4
# ▶️  Processing panic_15.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_15.mp4
# ▶️  Processing panic_16.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_16.mp4
# ▶️  Processing panic_17.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_17.mp4
# ▶️  Processing panic_18.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_18.mp4
# ▶️  Processing panic_19.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_19.mp4
# ▶️  Processing panic_20.mp4...
# ✅ Saved: /content/panic_heatmap_flow_vectors/heatmap_flow_panic_20.mp4
# 🎉 All enhanced heatmap + clean flow videos created.
